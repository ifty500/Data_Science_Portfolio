# %% [markdown]
# # Project: Viral Tweets
#
# In this project, we are going to use the K-Nearest Neighbor algorithm to predict whether a tweet will go viral. Before jumping into using the classifier, let's first consider the problem we're trying to solve. Which features of a tweet are most closely linked to its popularity? Maybe the number of hashtags or the number of links in the tweet strongly influences its popularity. Maybe its virality is dependent on how many followers the person has. Maybe it's something more subtle like the specific language used in the tweets.
#
# Let's explore these options by looking at the data we have available to us. We've imported the dataset and printed the following information:
#
# * The total number of tweets in the dataset.
# * The columns, or features, of the dataset.
# * The text of the first tweet in the dataset.
#
# Some of these features are dictionaries. For example, the feature `"user"` is a dictionary. We might want to use some of the information found in these sub-dictionaries. Print `all_tweets.loc[0]["user"]` to see what the `"user"` feature looks like.
#
# After printing that, try printing just the `"location"` found in that `"user"` dictionary. For example, `all_tweets.loc[0]["user"]["screen_name"]` would give you only the screen name associated with the first tweet.

# %%
import pandas as pd

all_tweets = pd.read_json("random_tweets.json", lines=True)

print(len(all_tweets))
print(all_tweets.columns)
print(all_tweets.loc[0]['text'])
print(all_tweets.loc[0]['user']['location'])
# Out:
# 11099
# Index(['contributors', 'coordinates', 'created_at', 'entities',
#        'extended_entities', 'favorite_count', 'favorited', 'geo', 'id',
#        'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id',
#        'in_reply_to_status_id_str', 'in_reply_to_user_id',
#        'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'metadata',
#        'place', 'possibly_sensitive', 'quoted_status', 'quoted_status_id',
#        'quoted_status_id_str', 'retweet_count', 'retweeted',
#        'retweeted_status', 'source', 'text', 'truncated', 'user',
#        'withheld_in_countries'],
#       dtype='object')
# RT @KWWLStormTrack7: We are more than a month into summer but the days are getting shorter. The sunrise is about 25 minutes later on July 3…
# Waterloo, Iowa

# %%
all_tweets.head()
# Out:
#    contributors coordinates          created_at  \
# 0           NaN        None 2018-07-31 13:34:40
# 1           NaN        None 2018-07-31 13:34:40
# 2           NaN        None 2018-07-31 13:34:40
# 3           NaN        None 2018-07-31 13:34:40
# 4           NaN        None 2018-07-31 13:34:40
#
#                                             entities extended_entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
# 4  {'hashtags': [], 'symbols': [], 'user_mentions...               NaN
#
#    favorite_count  favorited   geo                   id               id_str  \
# 0               0      False  None  1024287229525598210  1024287229525598208
# 1               0      False  None  1024287229512953856  1024287229512953856
# 2               0      False  None  1024287229504569344  1024287229504569344
# 3               0      False  None  1024287229496029190  1024287229496029184
# 4               0      False  None  1024287229492031490  1024287229492031488
#
#    ...                                   retweeted_status  \
# 0  ...  {'created_at': 'Mon Jul 30 16:49:41 +0000 2018...
# 1  ...                                                NaN
# 2  ...  {'created_at': 'Tue Jul 31 11:03:32 +0000 2018...
# 3  ...  {'created_at': 'Tue Jul 31 11:00:41 +0000 2018...
# 4  ...  {'created_at': 'Tue Jul 31 12:30:05 +0000 2018...
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  truncated  \
# 0  RT @KWWLStormTrack7: We are more than a month ...      False
# 1  @hail_ee23 Thanks love its just the feeling of...      False
# 2  RT @TransMediaWatch: Pink News has more on the...      False
# 3  RT @realDonaldTrump: One of the reasons we nee...      False
# 4  RT @First5App: This hearing of His Word doesn’...      False
#
#                                                 user  withheld_in_countries  \
# 0  {'id': 145388018, 'id_str': '145388018', 'name...                    NaN
# 1  {'id': 2407992339, 'id_str': '2407992339', 'na...                    NaN
# 2  {'id': 901579698223931392, 'id_str': '90157969...                    NaN
# 3  {'id': 23438548, 'id_str': '23438548', 'name':...                    NaN
# 4  {'id': 942424782, 'id_str': '942424782', 'name...                    NaN
#
#   is_viral tweet_length followers_count  friends_count
# 0        0          140             215            335
# 1        0           77             199            203
# 2        0          140             196            558
# 3        1          140            3313           2272
# 4        0          140             125            273
#
# [5 rows x 35 columns]

# %% [markdown]
# # Defining Viral Tweets
#
# A K-Nearest Neighbor classifier is a supervised machine learning algorithm, and as a result, we need to have a dataset with tagged labels. For this specific example, we need a dataset where every tweet is marked as viral or not viral. Unfortunately, this isn't a feature of our dataset &mdash; we'll need to make it ourselves.
#
# So how do we define a viral tweet? A good place to start is to look at the number of retweets the tweet has. This can be found using the feature `"retweet_count"`. Let's say we wanted to create a column called `is_viral` that is a `1` if the tweet had more than `5` retweets and `0` otherwise. We could do that like this:
#
# ```py
# all_tweets['is_viral'] = np.where(all_tweets['retweet_count'] > 5, 1, 0)
# ```
#
# Instead of using `5` as the benchmark for a viral tweet, let's use the median number of retweets. You can find that by calling the `median()` function on `all_tweets["retweet_count"]`. Print the median number of retweets to understand what this threshold is.
#
# Print the number of viral tweets and non-viral tweets. You can do this using `all_tweets['is_viral'].value_counts()`.
#
# After finishing this project, consider coming back and playing with this threshold number. How do you think your model would work if it was trying to find incredibly viral tweets? For example, how would it work if it were looking for tweets with 1000 or more retweets?

# %%
import numpy as np

median_retweets = all_tweets['retweet_count'].median()
print(median_retweets)
all_tweets['is_viral'] = np.where(all_tweets['retweet_count'] >= median_retweets, 1, 0)
print(all_tweets['is_viral'].value_counts())
# Out:
# 13.0
# 1    5591
# 0    5508
# Name: is_viral, dtype: int64

# %% [markdown]
# # Making Features
#
# Now that we've created a label for every tweet in our dataset, we can begin thinking about which features might determine whether a tweet is viral. We can create new columns in our dataset to represent these features. For example, let's say we think the length of a tweet might be a valuable feature. The following line creates a new column containing the length of the tweet.
#
# ```py
# all_tweets['tweet_length'] = all_tweets.apply(lambda tweet: len(tweet['text']), axis=1)
# ```
#
# Setting `axis = 1` creates a new column rather than a new row.
#
# Create a new column called `followers_count` that contains the number of followers of each user. You can find this information in `tweet['user']['followers_count']`. Do the same for `friends_count`.
#
# For the rest of this project, we will be using these three features, but we encourage you to create your own. Here are some potential ideas for more features.
#
# * The number of hashtags in the tweet. You can find this by looking at the `text` of the tweet and using the `.count()` function with `#` as a parameter.
# * The number of links in the tweet. Using a similar strategy to the one above, use `.count()` to count the number of times `http` appears in the tweet.
# * The number of words in the tweet. Call `.split()` on the `text` of a tweet. This will give you a list of the words in the tweet. Find the length of that list.
# * The average length of the words in the tweet.

# %%
all_tweets['tweet_length'] = all_tweets.apply(lambda tweet: len(tweet['text']), axis=1)
all_tweets['followers_count'] = all_tweets.apply(lambda tweet: tweet['user']['followers_count'], axis=1)
all_tweets['friends_count'] = all_tweets.apply(lambda tweet: tweet['user']['friends_count'], axis=1)
all_tweets
# Out:
#        contributors coordinates          created_at  \
# 0               NaN        None 2018-07-31 13:34:40
# 1               NaN        None 2018-07-31 13:34:40
# 2               NaN        None 2018-07-31 13:34:40
# 3               NaN        None 2018-07-31 13:34:40
# 4               NaN        None 2018-07-31 13:34:40
# 5               NaN        None 2018-07-31 13:34:40
# 6               NaN        None 2018-07-31 13:34:40
# 7               NaN        None 2018-07-31 13:34:40
# 8               NaN        None 2018-07-31 13:34:40
# 9               NaN        None 2018-07-31 13:34:40
# 10              NaN        None 2018-07-31 13:34:40
# 11              NaN        None 2018-07-31 13:34:40
# 12              NaN        None 2018-07-31 13:34:40
# 13              NaN        None 2018-07-31 13:34:40
# 14              NaN        None 2018-07-31 13:34:40
# 15              NaN        None 2018-07-31 13:34:40
# 16              NaN        None 2018-07-31 13:34:40
# 17              NaN        None 2018-07-31 13:34:40
# 18              NaN        None 2018-07-31 13:34:40
# 19              NaN        None 2018-07-31 13:34:40
# 20              NaN        None 2018-07-31 13:34:40
# 21              NaN        None 2018-07-31 13:34:40
# 22              NaN        None 2018-07-31 13:34:40
# 23              NaN        None 2018-07-31 13:34:40
# 24              NaN        None 2018-07-31 13:34:40
# 25              NaN        None 2018-07-31 13:34:40
# 26              NaN        None 2018-07-31 13:34:40
# 27              NaN        None 2018-07-31 13:34:40
# 28              NaN        None 2018-07-31 13:34:40
# 29              NaN        None 2018-07-31 13:34:40
# ...             ...         ...                 ...
# 11069           NaN        None 2018-07-31 13:34:13
# 11070           NaN        None 2018-07-31 13:34:13
# 11071           NaN        None 2018-07-31 13:34:13
# 11072           NaN        None 2018-07-31 13:34:13
# 11073           NaN        None 2018-07-31 13:34:13
# 11074           NaN        None 2018-07-31 13:34:13
# 11075           NaN        None 2018-07-31 13:34:13
# 11076           NaN        None 2018-07-31 13:34:13
# 11077           NaN        None 2018-07-31 13:34:13
# 11078           NaN        None 2018-07-31 13:34:13
# 11079           NaN        None 2018-07-31 13:34:13
# 11080           NaN        None 2018-07-31 13:34:13
# 11081           NaN        None 2018-07-31 13:34:13
# 11082           NaN        None 2018-07-31 13:34:13
# 11083           NaN        None 2018-07-31 13:34:13
# 11084           NaN        None 2018-07-31 13:34:13
# 11085           NaN        None 2018-07-31 13:34:13
# 11086           NaN        None 2018-07-31 13:34:13
# 11087           NaN        None 2018-07-31 13:34:13
# 11088           NaN        None 2018-07-31 13:34:13
# 11089           NaN        None 2018-07-31 13:34:13
# 11090           NaN        None 2018-07-31 13:34:13
# 11091           NaN        None 2018-07-31 13:34:13
# 11092           NaN        None 2018-07-31 13:34:13
# 11093           NaN        None 2018-07-31 13:34:13
# 11094           NaN        None 2018-07-31 13:34:13
# 11095           NaN        None 2018-07-31 13:34:13
# 11096           NaN        None 2018-07-31 13:34:13
# 11097           NaN        None 2018-07-31 13:34:13
# 11098           NaN        None 2018-07-31 13:34:13
#
#                                                 entities  \
# 0      {'hashtags': [], 'symbols': [], 'user_mentions...
# 1      {'hashtags': [], 'symbols': [], 'user_mentions...
# 2      {'hashtags': [], 'symbols': [], 'user_mentions...
# 3      {'hashtags': [], 'symbols': [], 'user_mentions...
# 4      {'hashtags': [], 'symbols': [], 'user_mentions...
# 5      {'hashtags': [], 'symbols': [], 'user_mentions...
# 6      {'hashtags': [], 'symbols': [], 'user_mentions...
# 7      {'hashtags': [], 'symbols': [], 'user_mentions...
# 8      {'hashtags': [], 'symbols': [], 'user_mentions...
# 9      {'hashtags': [], 'symbols': [], 'user_mentions...
# 10     {'hashtags': [], 'symbols': [], 'user_mentions...
# 11     {'hashtags': [], 'symbols': [], 'user_mentions...
# 12     {'hashtags': [], 'symbols': [], 'user_mentions...
# 13     {'hashtags': [], 'symbols': [], 'user_mentions...
# 14     {'hashtags': [{'text': 'RAW', 'indices': [132,...
# 15     {'hashtags': [], 'symbols': [], 'user_mentions...
# 16     {'hashtags': [], 'symbols': [], 'user_mentions...
# 17     {'hashtags': [], 'symbols': [], 'user_mentions...
# 18     {'hashtags': [], 'symbols': [], 'user_mentions...
# 19     {'hashtags': [], 'symbols': [], 'user_mentions...
# 20     {'hashtags': [], 'symbols': [], 'user_mentions...
# 21     {'hashtags': [], 'symbols': [], 'user_mentions...
# 22     {'hashtags': [{'text': 'Venom', 'indices': [64...
# 23     {'hashtags': [], 'symbols': [], 'user_mentions...
# 24     {'hashtags': [{'text': 'inovation', 'indices':...
# 25     {'hashtags': [], 'symbols': [], 'user_mentions...
# 26     {'hashtags': [], 'symbols': [], 'user_mentions...
# 27     {'hashtags': [], 'symbols': [], 'user_mentions...
# 28     {'hashtags': [], 'symbols': [], 'user_mentions...
# 29     {'hashtags': [{'text': 'Saakshyam', 'indices':...
# ...                                                  ...
# 11069  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11070  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11071  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11072  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11073  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11074  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11075  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11076  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11077  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11078  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11079  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11080  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11081  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11082  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11083  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11084  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11085  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11086  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11087  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11088  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11089  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11090  {'hashtags': [{'text': 'Mongolia', 'indices': ...
# 11091  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11092  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11093  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11094  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11095  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11096  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11097  {'hashtags': [], 'symbols': [], 'user_mentions...
# 11098  {'hashtags': [], 'symbols': [], 'user_mentions...
#
#                                        extended_entities  favorite_count  \
# 0                                                    NaN               0
# 1                                                    NaN               0
# 2                                                    NaN               0
# 3                                                    NaN               0
# 4                                                    NaN               0
# 5                                                    NaN               0
# 6                                                    NaN               0
# 7                                                    NaN               0
# 8                                                    NaN               0
# 9                                                    NaN               0
# 10                                                   NaN               0
# 11                                                   NaN               0
# 12                                                   NaN               0
# 13                                                   NaN               0
# 14                                                   NaN               0
# 15                                                   NaN               0
# 16     {'media': [{'id': 1024007278167564293, 'id_str...               0
# 17                                                   NaN               0
# 18                                                   NaN               0
# 19     {'media': [{'id': 1024286323283251201, 'id_str...               0
# 20                                                   NaN               0
# 21                                                   NaN               0
# 22     {'media': [{'id': 1024268216636329984, 'id_str...               0
# 23                                                   NaN               0
# 24                                                   NaN               0
# 25                                                   NaN               0
# 26                                                   NaN               0
# 27                                                   NaN               0
# 28                                                   NaN               0
# 29                                                   NaN               0
# ...                                                  ...             ...
# 11069  {'media': [{'id': 1023624458651688961, 'id_str...               0
# 11070                                                NaN               0
# 11071                                                NaN               0
# 11072                                                NaN               0
# 11073  {'media': [{'id': 1023593605787615232, 'id_str...               0
# 11074                                                NaN               0
# 11075                                                NaN               0
# 11076  {'media': [{'id': 924202348062302208, 'id_str'...               0
# 11077  {'media': [{'id': 1024143990524850176, 'id_str...               0
# 11078                                                NaN               0
# 11079                                                NaN               0
# 11080                                                NaN               0
# 11081                                                NaN               0
# 11082                                                NaN               0
# 11083                                                NaN               0
# 11084                                                NaN               0
# 11085                                                NaN               0
# 11086  {'media': [{'id': 1024286086972022784, 'id_str...               0
# 11087                                                NaN               0
# 11088                                                NaN               0
# 11089                                                NaN               0
# 11090                                                NaN               0
# 11091                                                NaN               0
# 11092                                                NaN               0
# 11093                                                NaN               0
# 11094                                                NaN               0
# 11095  {'media': [{'id': 1021301225277480960, 'id_str...               0
# 11096                                                NaN               0
# 11097                                                NaN               0
# 11098                                                NaN               0
#
#        favorited   geo                   id               id_str  ...  \
# 0          False  None  1024287229525598210  1024287229525598208  ...
# 1          False  None  1024287229512953856  1024287229512953856  ...
# 2          False  None  1024287229504569344  1024287229504569344  ...
# 3          False  None  1024287229496029190  1024287229496029184  ...
# 4          False  None  1024287229492031490  1024287229492031488  ...
# 5          False  None  1024287229491994625  1024287229491994624  ...
# 6          False  None  1024287229454233605  1024287229454233600  ...
# 7          False  None  1024287229445734400  1024287229445734400  ...
# 8          False  None  1024287229441658880  1024287229441658880  ...
# 9          False  None  1024287229424947201  1024287229424947200  ...
# 10         False  None  1024287229416431618  1024287229416431616  ...
# 11         False  None  1024287229408096256  1024287229408096256  ...
# 12         False  None  1024287229361963008  1024287229361963008  ...
# 13         False  None  1024287229332602881  1024287229332602880  ...
# 14         False  None  1024287229332545536  1024287229332545536  ...
# 15         False  None  1024287229324275712  1024287229324275712  ...
# 16         False  None  1024287229307510784  1024287229307510784  ...
# 17         False  None  1024287229294854144  1024287229294854144  ...
# 18         False  None  1024287229273767937  1024287229273767936  ...
# 19         False  None  1024287229269757953  1024287229269757952  ...
# 20         False  None  1024287229265334272  1024287229265334272  ...
# 21         False  None  1024287229219430401  1024287229219430400  ...
# 22         False  None  1024287229215211521  1024287229215211520  ...
# 23         False  None  1024287229202579456  1024287229202579456  ...
# 24         False  None  1024287229202464768  1024287229202464768  ...
# 25         False  None  1024287229198446594  1024287229198446592  ...
# 26         False  None  1024287229198393345  1024287229198393344  ...
# 27         False  None  1024287229185863680  1024287229185863680  ...
# 28         False  None  1024287229169025024  1024287229169025024  ...
# 29         False  None  1024287229156515841  1024287229156515840  ...
# ...          ...   ...                  ...                  ...  ...
# 11069      False  None  1024287114677157888  1024287114677157888  ...
# 11070      False  None  1024287114672754688  1024287114672754688  ...
# 11071      False  None  1024287114664411136  1024287114664411136  ...
# 11072      False  None  1024287114635169793  1024287114635169792  ...
# 11073      False  None  1024287114622582785  1024287114622582784  ...
# 11074      False  None  1024287114622427136  1024287114622427136  ...
# 11075      False  None  1024287114618437632  1024287114618437632  ...
# 11076      False  None  1024287114618228736  1024287114618228736  ...
# 11077      False  None  1024287114610049024  1024287114610049024  ...
# 11078      False  None  1024287114609999872  1024287114609999872  ...
# 11079      False  None  1024287114605801472  1024287114605801472  ...
# 11080      False  None  1024287114605678592  1024287114605678592  ...
# 11081      False  None  1024287114605654017  1024287114605654016  ...
# 11082      False  None  1024287114597462016  1024287114597462016  ...
# 11083      False  None  1024287114589085696  1024287114589085696  ...
# 11084      False  None  1024287114559717377  1024287114559717376  ...
# 11085      False  None  1024287114555478016  1024287114555478016  ...
# 11086      False  None  1024287114538692608  1024287114538692608  ...
# 11087      False  None  1024287114521923584  1024287114521923584  ...
# 11088      False  None  1024287114513403904  1024287114513403904  ...
# 11089      False  None  1024287114509406209  1024287114509406208  ...
# 11090      False  None  1024287114488414209  1024287114488414208  ...
# 11091      False  None  1024287114480025600  1024287114480025600  ...
# 11092      False  None  1024287114480021504  1024287114480021504  ...
# 11093      False  None  1024287114475786240  1024287114475786240  ...
# 11094      False  None  1024287114463195137  1024287114463195136  ...
# 11095      False  None  1024287114459074562  1024287114459074560  ...
# 11096      False  None  1024287114459074560  1024287114459074560  ...
# 11097      False  None  1024287114442301442  1024287114442301440  ...
# 11098      False  None  1024287114442272768  1024287114442272768  ...
#
#                                         retweeted_status  \
# 0      {'created_at': 'Mon Jul 30 16:49:41 +0000 2018...
# 1                                                    NaN
# 2      {'created_at': 'Tue Jul 31 11:03:32 +0000 2018...
# 3      {'created_at': 'Tue Jul 31 11:00:41 +0000 2018...
# 4      {'created_at': 'Tue Jul 31 12:30:05 +0000 2018...
# 5      {'created_at': 'Tue Jul 31 12:56:05 +0000 2018...
# 6                                                    NaN
# 7      {'created_at': 'Sun Jul 29 08:08:13 +0000 2018...
# 8      {'created_at': 'Tue Jul 31 06:00:03 +0000 2018...
# 9      {'created_at': 'Mon Jul 30 16:06:30 +0000 2018...
# 10                                                   NaN
# 11                                                   NaN
# 12     {'created_at': 'Mon Jul 30 21:40:05 +0000 2018...
# 13                                                   NaN
# 14     {'created_at': 'Tue Jul 31 13:24:52 +0000 2018...
# 15                                                   NaN
# 16     {'created_at': 'Mon Jul 30 19:02:15 +0000 2018...
# 17     {'created_at': 'Tue Jul 31 06:50:09 +0000 2018...
# 18     {'created_at': 'Tue Jul 31 10:31:08 +0000 2018...
# 19     {'created_at': 'Tue Jul 31 13:31:04 +0000 2018...
# 20     {'created_at': 'Tue Jul 31 06:15:17 +0000 2018...
# 21                                                   NaN
# 22     {'created_at': 'Tue Jul 31 13:00:01 +0000 2018...
# 23                                                   NaN
# 24     {'created_at': 'Tue Jul 31 11:18:26 +0000 2018...
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28     {'created_at': 'Mon Jul 30 20:25:44 +0000 2018...
# 29                                                   NaN
# ...                                                  ...
# 11069  {'created_at': 'Sun Jul 29 17:42:06 +0000 2018...
# 11070                                                NaN
# 11071  {'created_at': 'Tue Jul 31 13:02:04 +0000 2018...
# 11072  {'created_at': 'Tue Jul 31 13:14:41 +0000 2018...
# 11073  {'created_at': 'Tue Jul 31 04:40:00 +0000 2018...
# 11074                                                NaN
# 11075  {'created_at': 'Tue Jul 31 00:46:25 +0000 2018...
# 11076  {'created_at': 'Tue Jul 31 10:43:24 +0000 2018...
# 11077  {'created_at': 'Tue Jul 31 04:05:35 +0000 2018...
# 11078                                                NaN
# 11079                                                NaN
# 11080  {'created_at': 'Sun Jul 29 00:29:56 +0000 2018...
# 11081                                                NaN
# 11082  {'created_at': 'Thu May 03 12:52:44 +0000 2018...
# 11083  {'created_at': 'Mon Jul 30 23:03:52 +0000 2018...
# 11084                                                NaN
# 11085  {'created_at': 'Sun Jul 29 17:43:14 +0000 2018...
# 11086                                                NaN
# 11087  {'created_at': 'Tue Jul 31 13:15:04 +0000 2018...
# 11088  {'created_at': 'Tue Jul 31 13:30:02 +0000 2018...
# 11089                                                NaN
# 11090                                                NaN
# 11091  {'created_at': 'Tue Jul 31 08:23:49 +0000 2018...
# 11092  {'created_at': 'Sat Jul 28 19:14:56 +0000 2018...
# 11093  {'created_at': 'Tue Jul 31 13:21:31 +0000 2018...
# 11094  {'created_at': 'Mon Jul 30 13:19:17 +0000 2018...
# 11095  {'created_at': 'Mon Jul 30 17:48:07 +0000 2018...
# 11096                                                NaN
# 11097  {'created_at': 'Tue Jul 31 13:08:33 +0000 2018...
# 11098                                                NaN
#
#                                                   source  \
# 0      <a href="http://twitter.com/download/android" ...
# 1      <a href="http://twitter.com/download/iphone" r...
# 2      <a href="http://twitter.com/download/iphone" r...
# 3      <a href="http://twitter.com/download/android" ...
# 4      <a href="http://twitter.com/download/iphone" r...
# 5      <a href="http://twitter.com/download/android" ...
# 6      <a href="https://ifttt.com" rel="nofollow">IFT...
# 7      <a href="http://twitter.com/download/android" ...
# 8      <a href="http://twitter.com/download/android" ...
# 9      <a href="http://twitter.com/download/iphone" r...
# 10     <a href="http://twitter.com/download/android" ...
# 11     <a href="http://twitter.com/download/iphone" r...
# 12     <a href="http://twitter.com/download/android" ...
# 13     <a href="http://twitter.com" rel="nofollow">Tw...
# 14     <a href="http://twitter.com/download/android" ...
# 15     <a href="http://twitter.com/download/iphone" r...
# 16     <a href="http://twitter.com/download/android" ...
# 17     <a href="http://twitter.com/download/iphone" r...
# 18     <a href="http://twitter.com/download/iphone" r...
# 19     <a href="http://twitter.com/download/iphone" r...
# 20     <a href="http://twitter.com" rel="nofollow">Tw...
# 21     <a href="http://twitter.com/download/android" ...
# 22     <a href="http://twitter.com/download/iphone" r...
# 23     <a href="http://twitter.com" rel="nofollow">Tw...
# 24     <a href="https://mobile.twitter.com" rel="nofo...
# 25     <a href="http://twitter.com/download/iphone" r...
# 26     <a href="http://twitter.com/download/iphone" r...
# 27     <a href="http://twitter.com/download/android" ...
# 28     <a href="http://twitter.com/download/iphone" r...
# 29     <a href="http://twitter.com/download/android" ...
# ...                                                  ...
# 11069  <a href="http://twitter.com/download/iphone" r...
# 11070  <a href="http://twitter.com/download/iphone" r...
# 11071  <a href="https://mobile.twitter.com" rel="nofo...
# 11072  <a href="http://twitter.com/#!/download/ipad" ...
# 11073  <a href="http://twitter.com/download/iphone" r...
# 11074  <a href="http://twitter.com" rel="nofollow">Tw...
# 11075  <a href="http://twitter.com/download/iphone" r...
# 11076  <a href="http://twitter.com/download/android" ...
# 11077  <a href="https://mobile.twitter.com" rel="nofo...
# 11078  <a href="http://twitter.com/download/android" ...
# 11079  <a href="http://twitter.com" rel="nofollow">Tw...
# 11080  <a href="http://twitter.com/download/iphone" r...
# 11081  <a href="https://www.onedirect.in/" rel="nofol...
# 11082  <a href="http://twitter.com/download/iphone" r...
# 11083  <a href="http://twitter.com/download/iphone" r...
# 11084  <a href="http://twitter.com/download/android" ...
# 11085  <a href="http://twitter.com/download/iphone" r...
# 11086  <a href="https://ifttt.com" rel="nofollow">IFT...
# 11087  <a href="http://twitter.com/download/android" ...
# 11088  <a href="https://twitterrific.com/ios" rel="no...
# 11089  <a href="http://twitter.com/download/iphone" r...
# 11090  <a href="http://twitter.com" rel="nofollow">Tw...
# 11091  <a href="http://twitter.com/download/iphone" r...
# 11092  <a href="http://twitter.com/download/iphone" r...
# 11093  <a href="https://about.twitter.com/products/tw...
# 11094  <a href="http://twitter.com/download/android" ...
# 11095  <a href="http://twitter.com/download/android" ...
# 11096  <a href="http://twitter.com" rel="nofollow">Tw...
# 11097  <a href="http://twitter.com/download/iphone" r...
# 11098  <a href="http://twitter.com" rel="nofollow">Tw...
#
#                                                     text  truncated  \
# 0      RT @KWWLStormTrack7: We are more than a month ...      False
# 1      @hail_ee23 Thanks love its just the feeling of...      False
# 2      RT @TransMediaWatch: Pink News has more on the...      False
# 3      RT @realDonaldTrump: One of the reasons we nee...      False
# 4      RT @First5App: This hearing of His Word doesn’...      False
# 5      RT @attackerman: This is torture: “The staff t...      False
# 6      Did a demo of our Mobile Prototyping Kit at UX...       True
# 7      RT @itstae13: Stop getting rid of your pets be...      False
# 8      RT @RealErinCruz: Someone sent me a thought pr...      False
# 9      RT @penis_hernandez: when you ask how a white ...      False
# 10     @BengalGopi @AjaySha37627616 @GorkhaCheli Who ...       True
# 11     Happiest of birthdays to the big homie✊🏾 @rams...      False
# 12     RT @RBReich: According to Trump's legal team: ...      False
# 13     When will all these "criminals" against the Am...       True
# 14     RT @ProWrestlingMag: "He does charity work".\n...      False
# 15     there are some people you just don’t feel righ...      False
# 16     RT @Jeff__Benjamin: The new muse for @Versace ...      False
# 17     RT @__chloehenryxxo: My “can’t be arsed for wo...      False
# 18     RT @taegislut_: filo armys;\n\nwith every rt o...      False
# 19     RT @CauseWereGuys: The world needs this https:...      False
# 20     RT @alexandraerin: Toxic groundwater.\n\n"Let'...      False
# 21        @omo_ologo1 The Lord will perfect her healing.      False
# 22     RT @VenomMovie: The world has enough superhero...      False
# 23     I disagree with Amash on a lot but he has more...       True
# 24     RT @TheAgThinkTank: Agritom Australia fodder s...      False
# 25                  @Liquidachi Oh waittttt I found it 👀      False
# 26     @PodSaveAmerica @PodSaveAmerica - Is there edu...      False
# 27     @davidnwelton @lulu_says2 @TheRickWilson @Noah...       True
# 28     RT @TeannaTrump: We sucking dick in the middle...      False
# 29     An unexpected visit gets an overwhelming respo...       True
# ...                                                  ...        ...
# 11069  RT @mrmedina: I hate the internet 😭😭 🇩🇴 https:...      False
# 11070  she’s been bothering me since i woke up to let...       True
# 11071  RT @MorningMusumeMg: [12期 Blog] おふしょーっと@野中美希: ...      False
# 11072  RT @SethAbramson: What did I say: he'll do not...      False
# 11073  RT @ajplus: Ahed Tamimi is free. The Palestini...      False
# 11074         Robbers - The 1975 https://t.co/78RxRpKXfD      False
# 11075  RT @dearillegirl: to the person that made this...      False
# 11076  RT @gugudanofficiaI: ray: mariz said good nigh...      False
# 11077  RT @TheHiddenWorId: The oldest mask in the wor...      False
# 11078  . @torikravitz continues to make awesome conte...      False
# 11079  @bernadetterepis @jihadwatchRS @realDonaldTrum...       True
# 11080  RT @StxphhBby: Being afraid to check your bank...      False
# 11081  @born2helpothers  Hi Shubham, We tried calling...       True
# 11082  RT @Monabeee: @physco219 @realDonaldTrump I wa...      False
# 11083  RT @shujaxhaider: Capitalism has existed for l...      False
# 11084                    @SashaBanksWWE The boss ❤️❤️😘😘😍      False
# 11085  RT @pat0japussy: I tell my boyfriend and my fa...      False
# 11086  The iconic Bugatti Chiron has a price tag of m...      False
# 11087  RT @FreedomWorks: Trump's pit bulls on Capitol...      False
# 11088  RT @kylegriffin1: Ex-federal prosecutor Daniel...      False
# 11089  @StarSparkle_UK @Zionocracy It speaks volumes ...       True
# 11090  #Mongolia commits to #HealthForAll as the firs...       True
# 11091  RT @CoachChadScott: “Sometimes the best thing ...      False
# 11092  RT @newdrops1: Zilliqa’s first ICO to tackle t...      False
# 11093  RT @caseyliss: Secondly, my pal @BenRiceM’s wo...      False
# 11094  RT @sirDukeDevin: Trump keeps talking about "1...      False
# 11095  RT @AMAZlNGNATURE: Proud boy finding the best ...      False
# 11096  @ChrisDanicic @Mediaite @benshapiro The argume...       True
# 11097  RT @jodiequotepic: "I wanted to express the co...      False
# 11098  @w_terrence We shouldn't be making fun of peop...      False
#
#                                                     user  \
# 0      {'id': 145388018, 'id_str': '145388018', 'name...
# 1      {'id': 2407992339, 'id_str': '2407992339', 'na...
# 2      {'id': 901579698223931392, 'id_str': '90157969...
# 3      {'id': 23438548, 'id_str': '23438548', 'name':...
# 4      {'id': 942424782, 'id_str': '942424782', 'name...
# 5      {'id': 2157682506, 'id_str': '2157682506', 'na...
# 6      {'id': 33301256, 'id_str': '33301256', 'name':...
# 7      {'id': 751776402832171008, 'id_str': '75177640...
# 8      {'id': 515805787, 'id_str': '515805787', 'name...
# 9      {'id': 1616032410, 'id_str': '1616032410', 'na...
# 10     {'id': 873046208960278528, 'id_str': '87304620...
# 11     {'id': 1044040873, 'id_str': '1044040873', 'na...
# 12     {'id': 471648340, 'id_str': '471648340', 'name...
# 13     {'id': 3004236533, 'id_str': '3004236533', 'na...
# 14     {'id': 1540791426, 'id_str': '1540791426', 'na...
# 15     {'id': 900500030557233152, 'id_str': '90050003...
# 16     {'id': 831278571234721797, 'id_str': '83127857...
# 17     {'id': 2742888339, 'id_str': '2742888339', 'na...
# 18     {'id': 891639505899278336, 'id_str': '89163950...
# 19     {'id': 1641057344, 'id_str': '1641057344', 'na...
# 20     {'id': 1629143468, 'id_str': '1629143468', 'na...
# 21     {'id': 636199757, 'id_str': '636199757', 'name...
# 22     {'id': 780091510176026624, 'id_str': '78009151...
# 23     {'id': 15689618, 'id_str': '15689618', 'name':...
# 24     {'id': 1967884675, 'id_str': '1967884675', 'na...
# 25     {'id': 559880125, 'id_str': '559880125', 'name...
# 26     {'id': 723562169028231174, 'id_str': '72356216...
# 27     {'id': 16565006, 'id_str': '16565006', 'name':...
# 28     {'id': 750905456592359424, 'id_str': '75090545...
# 29     {'id': 170275758, 'id_str': '170275758', 'name...
# ...                                                  ...
# 11069  {'id': 961688007840542720, 'id_str': '96168800...
# 11070  {'id': 222628006, 'id_str': '222628006', 'name...
# 11071  {'id': 816260586409377793, 'id_str': '81626058...
# 11072  {'id': 186143353, 'id_str': '186143353', 'name...
# 11073  {'id': 2628727670, 'id_str': '2628727670', 'na...
# 11074  {'id': 3299489322, 'id_str': '3299489322', 'na...
# 11075  {'id': 910186369829474304, 'id_str': '91018636...
# 11076  {'id': 872829932036018176, 'id_str': '87282993...
# 11077  {'id': 193492961, 'id_str': '193492961', 'name...
# 11078  {'id': 2414934974, 'id_str': '2414934974', 'na...
# 11079  {'id': 68009672, 'id_str': '68009672', 'name':...
# 11080  {'id': 33768413, 'id_str': '33768413', 'name':...
# 11081  {'id': 2475273985, 'id_str': '2475273985', 'na...
# 11082  {'id': 216195586, 'id_str': '216195586', 'name...
# 11083  {'id': 74779891, 'id_str': '74779891', 'name':...
# 11084  {'id': 2628637847, 'id_str': '2628637847', 'na...
# 11085  {'id': 1623188185, 'id_str': '1623188185', 'na...
# 11086  {'id': 846102864376184832, 'id_str': '84610286...
# 11087  {'id': 62266869, 'id_str': '62266869', 'name':...
# 11088  {'id': 15886477, 'id_str': '15886477', 'name':...
# 11089  {'id': 15904911, 'id_str': '15904911', 'name':...
# 11090  {'id': 50158813, 'id_str': '50158813', 'name':...
# 11091  {'id': 58767738, 'id_str': '58767738', 'name':...
# 11092  {'id': 963306391082602496, 'id_str': '96330639...
# 11093  {'id': 720270668420374530, 'id_str': '72027066...
# 11094  {'id': 757363917609955328, 'id_str': '75736391...
# 11095  {'id': 510935782, 'id_str': '510935782', 'name...
# 11096  {'id': 3379100265, 'id_str': '3379100265', 'na...
# 11097  {'id': 2400047250, 'id_str': '2400047250', 'na...
# 11098  {'id': 964603155915816960, 'id_str': '96460315...
#
#        withheld_in_countries is_viral tweet_length followers_count  \
# 0                        NaN        0          140             215
# 1                        NaN        0           77             199
# 2                        NaN        0          140             196
# 3                        NaN        1          140            3313
# 4                        NaN        0          140             125
# 5                        NaN        1          139             128
# 6                        NaN        0          140             259
# 7                        NaN        1          139             113
# 8                        NaN        1          140            1200
# 9                        NaN        1          140              51
# 10                       NaN        0          140             119
# 11                       NaN        0           56             710
# 12                       NaN        1          140             307
# 13                       NaN        0          140               2
# 14                       NaN        1          136             424
# 15                       NaN        0          140              84
# 16                       NaN        1           69              84
# 17                       NaN        1           86              47
# 18                       NaN        1          139              44
# 19                       NaN        1           63             709
# 20                       NaN        1          140            6206
# 21                       NaN        0           46             310
# 22                       NaN        1          115              44
# 23                       NaN        0          140             585
# 24                       NaN        0          140            7427
# 25                       NaN        0           36             488
# 26                       NaN        0          136             128
# 27                       NaN        0          139             589
# 28                       NaN        1           88              48
# 29                       NaN        0          139             867
# ...                      ...      ...          ...             ...
# 11069                    NaN        1           63             162
# 11070                    NaN        0          140             216
# 11071                    NaN        1          140             314
# 11072                    NaN        1          139             847
# 11073                    NaN        1          138              21
# 11074                    NaN        0           42             396
# 11075                    NaN        1          140            1726
# 11076                    NaN        0          118              21
# 11077                    NaN        1           91             127
# 11078                    NaN        0           95             504
# 11079                    NaN        0          140             249
# 11080                    NaN        1          113             188
# 11081                    NaN        0          140          180661
# 11082                    NaN        1          140           18084
# 11083                    NaN        1          139             113
# 11084                    NaN        0           31              17
# 11085                    NaN        1          140             339
# 11086                    NaN        0          123             189
# 11087                    NaN        0          144             367
# 11088                    NaN        1          140            1794
# 11089                    NaN        0          140            2401
# 11090                    NaN        0          144            1191
# 11091                    NaN        0          140              21
# 11092                    NaN        0          140              39
# 11093                    NaN        0          139              58
# 11094                    NaN        1          140             509
# 11095                    NaN        1           75             462
# 11096                    NaN        0          140             135
# 11097                    NaN        0          140              59
# 11098                    NaN        0           75            1563
#
#        friends_count
# 0                335
# 1                203
# 2                558
# 3               2272
# 4                273
# 5                496
# 6                204
# 7                120
# 8               2970
# 9                399
# 10                64
# 11               505
# 12               923
# 13                47
# 14               268
# 15                78
# 16               657
# 17               151
# 18               111
# 19               495
# 20              2740
# 21               229
# 22               190
# 23               649
# 24              1453
# 25               738
# 26               162
# 27              2022
# 28                51
# 29               144
# ...              ...
# 11069            265
# 11070            236
# 11071           1495
# 11072            790
# 11073             76
# 11074            306
# 11075           4704
# 11076             23
# 11077            120
# 11078           1392
# 11079            401
# 11080            355
# 11081          15315
# 11082          19900
# 11083            567
# 11084            266
# 11085            267
# 11086            293
# 11087           1333
# 11088           2923
# 11089           2389
# 11090            507
# 11091            316
# 11092             54
# 11093            237
# 11094           1323
# 11095           1033
# 11096             90
# 11097            320
# 11098           1697
#
# [11099 rows x 35 columns]

# %% [markdown]
# # Normalizing The Data
#
# We've now made the columns that we want to feed into our classifier. Let's get rid of all the data that is no longer relevant. Create a variable named `labels` and set it equal to the `'is_viral'` column of all_tweets.
#
# If we had a dataframe named `df` we could get a single column named `A` like this:
#
# ```py
# one_column = df['A']
# ```
#
# Create a variable named `data` and set it equal to all of the columns that you created in the last step. Those columns are `tweet_length`, `followers_count`, and `friends_count`.
#
# When selecting multiple columns, the names of the columns should be in a list. Check out the example below to see how to select column `A` *and* `B`:
#
# ```py
# features = df[['A', 'B']]
# ```
#
# Now create a new variable named `scaled_data`. `scaled_data` should be the result of the `scale` function with `data` as a parameter. Also include the parameter `axis = 0`. This scales the *columns* as opposed to the rows.
#
# The scale function will normalize the data so all of the features will vary within the same range.
#
# Print `scaled_data[0]` to get a sense of what our data looks like.

# %%
from sklearn.preprocessing import scale

labels = all_tweets['is_viral']
data = all_tweets[['tweet_length','followers_count','friends_count']]
scaled_data = scale(data, axis=0)

print(scaled_data[0])
# Out:
# [ 0.6164054  -0.02878298 -0.14483305]

# %% [markdown]
# # Creating the Training Set and Test Set
#
# To evaluate the effectiveness of our classifier, we now split `scaled_data` and `labels` into a training set and test set using scikit-learn's `train_test_split` function. This function takes two required parameters: It takes the data, followed by the labels. Set the optional parameter `test_size` to be `0.2`. You can also set the `random_state` parameter so your code will randomly split the data in the same way as our solution code splits the data. We used `random_state = 1`. Remember, this function returns 4 items in this order:
#
# 1. The training data
# 2. The testing data
# 3. The training labels
# 4. The testing labels
#
# Store the results in variables named `train_data`, `test_data`, `train_labels`, and `test_labels`.

# %%
from sklearn.model_selection import train_test_split

train_data, test_data, train_labels, test_labels = train_test_split(scaled_data, labels, test_size = 0.3, random_state = 42)

# %% [markdown]
# # Using the Classifier
#
# We can finally use the K-Nearest Neighbor classifier. Let's test it using `k = 5`. Begin by creating a `KNeighborsClassifier` object named `classifier` with the parameter `n_neighbors` equal to `5`.
#
# Next, train `classifier` by calling the `.fit()` method with `train_data` and `train_labels` as parameters.
#
# Finally, let's test the model! Call `classifier`'s `.score()` method using `test_data` and `test_labels` as parameters. Print the results.

# %%
from sklearn.neighbors import KNeighborsClassifier

classifier = KNeighborsClassifier(n_neighbors = 5)
classifier.fit(train_data, train_labels)
pred = classifier.predict(test_data)
print(classifier.score(test_data, test_labels))
# Out:
# 0.587987987987988

# %%
# Out:
# Accuracy:0.587987987987988

# %% [markdown]
# # Choosing K
#
# We've tested our classifier with `k = 5`, but maybe there's a `k` that will work better. Let's test many different values for `k` and graph the results.
#
# First, create an empty list called `scores`. Next, create a for loop that has a variable `k` that begins at `1` and ends at `200`.
#
# Inside the for loop, create a `KNeighobrsClassifier` object named `classifier` with the parameter `n_neighbors` equal to `k`.
#
# Train `classifier` by calling the `.fit()` method with `train_data` and `train_labels` as parameters.
#
# Next, let's test the model! Call `classifier`'s `.score()` method using `test_data` and `test_labels` as parameters. `append` the result to `scores`.
#
# Finally, let's plot the results. Outside of the loop, use Matplotlib's `plot()` function. `plot()` takes two parameters &mdash; the data on the x-axis and the data on the y-axis. Data on the x-axis should be the values we used for `k`. In this case, `range(1,200)`.  Data on the y-axis should be `scores`. Make sure to call the `plt.show()` function after calling `plt.plot()`. This should take a couple of seconds to run!

# %%
import matplotlib.pyplot as plt

scores = []
for k in range(1, 200):
    classifier = KNeighborsClassifier(n_neighbors = k)
    classifier.fit(train_data, train_labels)
    scores.append(classifier.score(test_data, test_labels))
    
plt.plot(range(1,200), scores)
plt.show()

# %% [markdown]
# ## Conclusion
# The classifier gets better as `k` increases, but as `k` gets too high, underfitting starts to happen.
#
# By using the features `tweet_length`, `followers_count`, and `friends_count`, we were able to get up to around 63% accuracy. That is better than random, but still not exceptional.
